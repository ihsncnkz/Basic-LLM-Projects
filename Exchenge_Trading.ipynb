# %% [markdown]
# # Introduction
# In this project, I will create an AI assistant for exchange trading. I will use two datasets in this project. The first dataset is about news data and These news data are about Apple Company. The second dataset is about the Apple stock price dataset. Firstly I will prepare news data and then I will prepare stock data. I will use GPT-4o-mini for the AI assistant model.
#
# However, this study is a preliminary study. It cannot be used in any stock trading transactions because the artificial intelligence assistant will not work with 100% accuracy.
#
# **I warn you: please do not use this system for stock market purchases.**

# %%
# Download Python Library
# !pip install newsapi-python
# Out:
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.11/dist-packages (from newsapi-python) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0->newsapi-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0->newsapi-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0->newsapi-python) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0->newsapi-python) (2025.6.15)
# Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7

# %% [markdown]
# # News Data
# In this chapter, I will prepare a news dataset. I will take news with newsapi. I took the api key at the "newsapi.org".

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from newsapi import NewsApiClient
from google.colab import userdata
from datetime import datetime, timedelta

from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch
from typing import Tuple

import yfinance as yf

from openai import OpenAI

# %%
start_day = datetime.today() - timedelta(days=1)
end_day = start_day - timedelta(days=29)

# Year-Month-Day convert to format!
start_day_str = start_day.strftime('%Y-%m-%d')
end_day_str = end_day.strftime('%Y-%m-%d')

print("Yesterday:", start_day_str)
print("29 Days Ago:", end_day_str)
# Out:
# Yesterday: 2025-06-17
# 29 Days Ago: 2025-05-19

# %%
# I download the news datas.
newsapi = NewsApiClient(api_key=userdata.get("NEWS_API"))

all_articles = newsapi.get_everything(q='apple',
                                      from_param=start_day_str,
                                      to=end_day_str,
                                      language='en')

# %%
all_articles['articles']
# Out:
# [{'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Apple’s new Games app lets you challenge your friends',
#   'description': 'Apple is launching a new app that acts as a central hub for the games and gaming features across its platforms. The new Apple Games app combines Apple Arcade, App Store game recommendations, your App Store game library, and your friends list into a single loc…',
#   'url': 'https://www.theverge.com/news/678319/apple-games-app-wwdc-2025',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Apple-WWDC25-iPadOS-26-Games-app-250609_big.jpg.large_2x.jpg?quality=90&strip=all&crop=0%2C13.350785340314%2C100%2C73.298429319372&w=1200',
#   'publishedAt': '2025-06-09T18:09:03Z',
#   'content': 'Another gaming initiative from Apple thats meant to be a central hub for players.\r\nAnother gaming initiative from Apple thats meant to be a central hub for players.\r\nApple is launching a new app that… [+1675 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Dominic Preston',
#   'title': 'Apple’s DIY repair program now covers iPads',
#   'description': 'Apple is expanding its self-service repair program to cover a range of iPads, including mini, Air, and Pro models. The program opens tomorrow, at which point you’ll be able to order spare parts and repair kits for the Apple tablets. The program is mostly limi…',
#   'url': 'https://www.theverge.com/news/675475/apple-self-service-repair-progam-ipad-air-pro-mini',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/iPad_Mini_8.webp?quality=90&strip=all&crop=0,10.416314811687,100,79.167370376626',
#   'publishedAt': '2025-05-28T11:48:45Z',
#   'content': 'Recent iPad, mini, Air, and Pro models are now covered by official spare parts for self-service repair.\r\nRecent iPad, mini, Air, and Pro models are now covered by official spare parts for self-servic… [+1323 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Wes Davis, Jay Peters',
#   'title': 'Apple is ready to replace Game Center with a more Xbox-like gaming app',
#   'description': 'Apple plans to announce an app focused on video games for the iPhone, iPad, Mac, and Apple TV at its Worldwide Developer Conference next week, according to Bloomberg. The app will let you launch games you’ve installed on your devices and serve as a hub for th…',
#   'url': 'https://www.theverge.com/news/675241/apple-game-center-app-replace-rac7-sneaky-sasquatch-acquisition',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/04/STK071_APPLE_H.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-05-27T20:17:31Z',
#   'content': 'The company has also acquired RAC7, the developer of Sneaky Sasquatch.\r\nThe company has also acquired RAC7, the developer of Sneaky Sasquatch.\r\nApple plans to announce an app focused on video games f… [+1119 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple WWDC 2025: the 13 biggest announcements',
#   'description': 'Apple packed a bunch of major updates into its annual Worldwide Developer Conference keynote. During the event, the company showed off the sleek design refresh coming to its operating systems, as well as a mix of new features for the iPhone, iPad, Mac, AirPod…',
#   'url': 'https://www.theverge.com/news/682769/apple-wwdc-2025-biggest-announcements-ios-26',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Screenshot-2025-06-09-at-2.56.43%E2%80%AFPM.png?quality=90&strip=all&crop=0%2C6.8922688882944%2C100%2C86.215462223411&w=1200',
#   'publishedAt': '2025-06-09T19:04:31Z',
#   'content': 'Apple packed a bunch of major updates into its annual Worldwide Developer Conference keynote. During the event, the company showed off the sleek design refresh coming to its operating systems, as wel… [+5658 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Apple’s upgraded Siri might not arrive until next spring',
#   'description': 'Apple is aiming to launch the upgraded Siri that it originally previewed at WWDC 2024 in spring 2026 with iOS 26.4, according to Bloomberg. At WWDC last year, Apple showed off how Siri would be able to do things like understand your personal context or take a…',
#   'url': 'https://www.theverge.com/news/686498/apple-upgraded-siri-ios-26-4',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/DSC08596_processed.jpg.webp?quality=90&strip=all&crop=0%2C11.097693417406%2C100%2C77.804613165189&w=1200',
#   'publishedAt': '2025-06-12T21:45:33Z',
#   'content': 'It could launch with iOS 26.4.\r\nApple is aiming to launch the upgraded Siri that it originally previewed at WWDC 2024 in spring 2026 with iOS 26.4, according to Bloomberg.\r\nAt WWDC last year, Apple s… [+1254 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Allison Johnson',
#   'title': 'All the Android features Apple announced at WWDC',
#   'description': "Apple announcing Android features years after Google shipped them is a tale as old as time, but that doesn't make it any less fun to point out whenever it happens. This year's WWDC felt especially Android-y - not helped by Siri essentially sitting this year's…",
#   'url': 'https://www.theverge.com/apple-wwdc/686247/apple-wwdc-ios-26-android-features',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/DSC02062.jpg?quality=90&strip=all&crop=0%2C10.723165084465%2C100%2C78.55366983107&w=1200',
#   'publishedAt': '2025-06-12T18:49:04Z',
#   'content': 'A little Dub Dub deja vu.\r\nApple announcing Android features years after Google shipped them is a tale as old as time, but that doesnt make it any less fun to point out whenever it happens. This year… [+4262 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jacob Kastrenakes',
#   'title': 'Apple ordered to keep web links in the App Store',
#   'description': 'Apple will have to continue allowing web links and external payment options in the App Store after its request to halt a judge’s order was rejected today by a higher court. In April, a federal judge demanded that Apple begin allowing web links, cease restrict…',
#   'url': 'https://www.theverge.com/news/679946/apple-rejected-court-attempt-to-stop-app-store-web-links',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/STK468_APPLE_ANTITRUST_CVIRGINIA_C.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-04T21:53:46Z',
#   'content': 'An Appeals Court rejected Apples request to block an order enabling external links.\r\nAn Appeals Court rejected Apples request to block an order enabling external links.\r\nApple will have to continue a… [+2238 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Victoria Song, Alex Heath, Allison Johnson, Nilay Patel',
#   'title': 'WWDC 2025 live blog: a fresh new look at iOS, macOS, and more',
#   'description': "Conference season is underway, and today we're live at Apple Park in Cupertino, California, for this year's WWDC. While we got a glimpse of the Vision Pro in 2023 and a preview of Apple Intelligence in 2024, this year is a bit of a wild card. Rumor has it tha…",
#   'url': 'https://www.theverge.com/apple-event/677993/wwdc-2025-live-blog-apple-event-ios-ai',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Screenshot-2025-06-02-at-10.59.40%E2%80%AFAM.png?quality=90&strip=all&crop=0%2C12.492098892056%2C100%2C75.015802215888&w=1200',
#   'publishedAt': '2025-06-09T16:42:57Z',
#   'content': 'WWDC 2025 live blog: a fresh new look at iOS, macOS, and more\r\nSoftware redesigns, some new names, and probably more AI. Probably.\r\nWWDC 2025 live blog: a fresh new look at iOS, macOS, and more\r\nSoft… [+1474 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Dominic Preston',
#   'title': 'Trump threatens Apple with a 25 percent iPhone tariff',
#   'description': 'President Donald Trump has threatened Apple with a tariff of “at least 25 percent” just for its iPhones unless it moves production to the United States. “I have long ago informed Tim Cook of Apple that I expect their iPhone’s that will be sold in the United S…',
#   'url': 'https://www.theverge.com/news/673424/trump-apple-iphone-tariff-25-percent-india',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/25626299/247263_iphone_16_pro_AKrales_0832.jpg?quality=90&strip=all&crop=0%2C14.104857475276%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-05-23T11:51:05Z',
#   'content': 'President Donald Trump has threatened Apple with a tariff of “at least 25 percent” just for its iPhones unless it moves production to the United States.\n\n“I have long ago informed Tim Cook of Apple t… [+586 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jess Weatherbed',
#   'title': 'Jony Ive’s OpenAI device gets the Powell Jobs nod of approval',
#   'description': 'The mysterious AI gadget being created by OpenAI and former Apple design chief Jony Ive has been given the thumbs up from Laurene Powell Jobs. In a new interview published by The Financial Times, the two reminisce about Jony Ive’s time working at Apple alongs…',
#   'url': 'https://www.theverge.com/news/677921/jony-ive-openai-laurene-powell-jobs-interview',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/gettyimages-1438500402.jpg?quality=90&strip=all&crop=0%2C10.729474235474%2C100%2C78.541051529051&w=1200',
#   'publishedAt': '2025-06-02T10:33:58Z',
#   'content': 'Having invested in Ives startups, Powell Jobs stands to profit from the devices success.\r\nHaving invested in Ives startups, Powell Jobs stands to profit from the devices success.\r\nThe mysterious AI g… [+2336 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'iOS 26’s new ‘adaptive power’ mode dials back performance to save battery',
#   'description': 'Apple is working on a new “adaptive power” feature in iOS 26 that aims to make your battery last longer. In the iOS 26 developer beta, Apple describes the feature as a way for the iPhone to make “small performance adjustments to extend your battery life,” inc…',
#   'url': 'https://www.theverge.com/news/683797/ios-26s-new-adaptive-power-mode-dials-back-performance-to-save-battery',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/adaptive-power.jpg?quality=90&strip=all&crop=0%2C23.391962375903%2C100%2C53.239186654513&w=1200',
#   'publishedAt': '2025-06-09T21:30:43Z',
#   'content': 'The “Adaptive Power” option will exist alongside “Low Power Mode.”\r\n\n\nApple is working on a new “adaptive power” feature in iOS 26 that aims to make your battery last longer. In the iOS 26 developer … [+1346 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jennifer Pattison Tuohy',
#   'title': 'Apple Home is expanding its energy management features',
#   'description': 'Apple’s smart home didn’t get a single nod during the WWDC keynote, but it turns out there are some interesting developments coming to the Home app around energy management.\xa0 In a video posted to the Apple developer site this week, the company outlined its ne…',
#   'url': 'https://www.theverge.com/news/685733/apple-home-energykit-energy-management-ios26-wwdc',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Screenshot-2025-06-11-at-5.17.43%E2%80%AFPM.png?quality=90&strip=all&crop=0%2C3.3978066866336%2C100%2C93.204386626733&w=1200',
#   'publishedAt': '2025-06-11T21:34:22Z',
#   'content': 'Apples new EnergyKit framework lets developers tap into energy use data from the Home app to help reduce and schedule energy use of devices.\r\nApples smart home didnt get a single nod during the WWDC … [+2988 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Sam Byford',
#   'title': 'Oppo Find X8 Ultra Review: This Might Be the World’s Best Phone Camera',
#   'description': 'Apple, Samsung, and google have really fallen behind.',
#   'url': 'https://gizmodo.com/oppo-find-x8-ultra-review-this-might-be-the-worlds-best-phone-camera-2000609598',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/oppo-find-x8-ultra-review-9.jpg',
#   'publishedAt': '2025-06-01T13:00:05Z',
#   'content': 'I get itthe smartphone market is boring. Galaxy after iPhone after Pixel, year after year after yearat least if youre in the U.S. Even if youre into phone tech, it can be hard to feel enthusiastic ab… [+9982 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'The biggest changes coming to your iPhone with iOS 26',
#   'description': 'Apple just announced the next major software update for iPhones: iOS 26 (a jump from what, until recently, was expected to be called iOS 19), and it’s packed with a whole bunch of new features for your phone. The biggest change is a new design, but there are …',
#   'url': 'https://www.theverge.com/news/683738/apple-iphone-ios-26-changes-liquid-glass-wwdc-2025',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/lcimg-d70a06ea-da2e-4d1a-8598-b850e161dee5.jpeg?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#   'publishedAt': '2025-06-09T20:50:37Z',
#   'content': 'From a huge redesign to handy phone call features, heres whats coming next to iOS.\r\nFrom a huge redesign to handy phone call features, heres whats coming next to iOS.\r\nApple just announced the next m… [+3310 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple’s big updates for Intel-based Macs will end with Tahoe',
#   'description': 'Macs equipped with an Intel chip will no longer receive major software updates after the release of macOS Tahoe this fall. During the WWDC Platforms State of the Union keynote, Matthew Firlik, Apple’s senior director of developer relations, announced that mac…',
#   'url': 'https://www.theverge.com/news/683846/macos-tahoe-intel-x86-arm-m-cpu',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/intel-final.png?quality=90&strip=all&crop=0,24.134915252756,100,67.315961390434',
#   'publishedAt': '2025-06-09T22:14:18Z',
#   'content': 'Apple phased Intel-based Macs out of its product lines years ago, and now its cutting off software updates, too.\r\nMacs equipped with an Intel chip will no longer receive major software updates after … [+1495 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Craig Federighi confirms Apple’s first attempt at an AI Siri wasn’t good enough',
#   'description': 'In March, Apple delayed its upgraded Siri, saying that “it’s going to take us longer than we thought to deliver” the promised features. At WWDC this week, Apple’s SVP of software Craig Federighi and SVP of worldwide marketing Greg Joswiak shared more details …',
#   'url': 'https://www.theverge.com/news/685106/apple-ai-siri-delay-craig-federighi-greg-joswiak-wwdc-2025',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/lcimg-e6d8e442-b85b-4efb-801a-f54562a9216d.jpeg?quality=90&strip=all&crop=0%2C10.597538331207%2C100%2C78.804923337586&w=1200',
#   'publishedAt': '2025-06-10T23:47:26Z',
#   'content': 'This just doesnt work reliably enough to be an Apple product.\r\nThis just doesnt work reliably enough to be an Apple product.\r\nIn March, Apple delayed its upgraded Siri, saying that its going to take … [+1756 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Julian Chokkattu',
#   'title': "It's Time to Kill Siri",
#   'description': 'After almost 10 years, Google Assistant was recently axed in favor of Gemini. Siri gets a bad rap—now is the time for Apple to make a change too.',
#   'url': 'https://www.wired.com/story/its-time-to-kill-siri/',
#   'urlToImage': 'https://media.wired.com/photos/67ebff033fd281d67a1579b0/191:100/w_1280,c_limit/iPhone-16-Pro-Siri-Reviewer-Photo-SOURCE-Julian-Chokkattu-(no-border).jpg',
#   'publishedAt': '2025-06-09T11:09:49Z',
#   'content': "If you've had a passing interest in Apple over the past year, you've likely heard of the company's struggles in the AI race. Apple Intelligence, which arrived slightly late after the launch of the iP… [+3117 chars]"},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Dominic Preston',
#   'title': 'How to watch Apple’s WWDC 2025 keynote',
#   'description': 'With Google and Microsoft’s developer conferences out of the way, now it’s time for Apple’s WWDC. The Cupertino company is gearing up to unveil new versions (and new numbers) for all its operating systems, as well as taking a second step at convincing everyon…',
#   'url': 'https://www.theverge.com/news/680467/apple-wwdc-2025-keynote-livestream-ios-macos-how-to-watch',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/03/Apple-WWDC25-event-branding.jpg?quality=90&strip=all&crop=1%2C3.1038976148924%2C95.8%2C89.168121000582&w=1200',
#   'publishedAt': '2025-06-09T13:26:30Z',
#   'content': 'With Google and Microsoft’s developer conferences out of the way, now it’s time for Apple’s WWDC. The Cupertino company is gearing up to unveil new versions (and new numbers) for all its operating sy… [+2871 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Apple Didn’t Design Controllers for the Vision Pro, but It Gave Us the Next Best Thing',
#   'description': 'Would you pay $3,500 for an Apple Vision Pro with better Personas or controller support?',
#   'url': 'https://gizmodo.com/apple-didnt-design-controllers-for-the-vision-pro-but-it-gave-us-the-next-best-thing-2000613200',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/WWDC25-Apple-Vision-Pro-Controllers-Pickle-Pro-1200x675.jpg',
#   'publishedAt': '2025-06-09T19:45:23Z',
#   'content': 'Apples bulky, powerful, occasionally beautiful, and way-too-expensive XR headset, the Vision Pro, is coming into the fold of Apples software ecosystem as well as the wider VR market. At WWDC25, Apple… [+3939 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Gizmodo Deals',
#   'title': 'Amazon Is Going All In, This PlayStation VR Bundle With Horizon Call of the Mountain Now Costs Peanuts',
#   'description': 'It’s ten times cheaper than the Apple Vision Pro and still feels very real for VR.',
#   'url': 'https://gizmodo.com/amazon-is-going-all-in-this-playstation-vr-bundle-with-horizon-call-of-the-mountain-now-costs-peanuts-2000611610',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2024/12/PlayStation-VR2-Horizon.jpg',
#   'publishedAt': '2025-06-05T11:40:33Z',
#   'content': 'No need to hold out until Black Friday this year, though, because the current offer from Amazon on the PlayStation VR2 Horizon Call of the Mountain bundle is better than anything we saw last year wit… [+2953 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Apple could be adding camera controls and sleep detection to your AirPods',
#   'description': 'It sounds like Apple is preparing a big AirPods update for WWDC next week. A report from 9to5Mac says the company is working on a new feature that will let you control your iPhone or iPad’s camera with your AirPods. The feature will reportedly allow you to sn…',
#   'url': 'https://www.theverge.com/news/679930/apple-airpods-camera-controls-sleep-detection-wwdc-rumor',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/DSCF0036.webp?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-04T21:12:31Z',
#   'content': 'A new feature might let you snap a picture by tapping the stem of your AirPods.\r\nA new feature might let you snap a picture by tapping the stem of your AirPods.\r\nIt sounds like Apple is preparing a b… [+1175 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jess Weatherbed',
#   'title': 'Apple’s Journal app is finally coming to other platforms',
#   'description': 'After two years as an iPhone exclusive, Apple’s Journal app will soon be available on Mac and iPad. Apple announced at WWDC on Monday that its latest macOS 26 and iPadOS 26 updates will support the Journal app, which helps users track their daily activities a…',
#   'url': 'https://www.theverge.com/news/684163/apple-journal-app-ipad-mac-support-availability',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Apple-WWDC25-iPadOS-26-Journal-app-250609_big.jpg.large_2x.jpg?quality=90&strip=all&crop=0%2C13.350785340314%2C100%2C73.298429319372&w=1200',
#   'publishedAt': '2025-06-10T11:33:37Z',
#   'content': 'Being able to personalize Journal entries with doodles on iPad is a nice touch.\r\n\n\nAfter two years as an iPhone exclusive, Apple’s Journal app will soon be available on Mac and iPad. Apple announced … [+1213 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Tom Warren',
#   'title': 'Apple’s new design language is Liquid Glass',
#   'description': 'Apple is introducing a new Liquid Glass design across its software platforms today. It’s all about adding transparency and glass shine effects to Apple’s in-app interfaces across iOS 26, iPadOS 26, macOS Tahoe 26, watchOS 26, and tvOS 26. “[It’s] our broadest…',
#   'url': 'https://www.theverge.com/news/682636/apple-liquid-glass-design-theme-wwdc-2025',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/liquidglassmain.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-09T17:46:24Z',
#   'content': 'Liquid Glass is coming to iOS 26, iPadOS 26, macOS Tahoe 26, and more.\r\nLiquid Glass is coming to iOS 26, iPadOS 26, macOS Tahoe 26, and more.\r\nApple is introducing a new Liquid Glass design across i… [+2775 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew Liszewski',
#   'title': 'The first developer betas for iOS 26, macOS Tahoe, iPadOS 26, and more are dropping today',
#   'description': 'The first developer betas for iOS 26, iPadOS 26, watchOS 26, tvOS 26, visionOS 26, and macOS Tahoe are dropping today if you’re eager to try many of the new features and updates that Apple just announced. Everyone will have early access to the new versions of…',
#   'url': 'https://www.theverge.com/news/682871/apple-developer-beta-ios-26-watchos-26-macos-availability',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/apple_developer.jpg?quality=90&strip=all&crop=0,10.732984293194,100,78.534031413613',
#   'publishedAt': '2025-06-09T18:57:41Z',
#   'content': 'You can try out many of the new features, if youre okay with bugs and other unexpected issues.\r\nYou can try out many of the new features, if youre okay with bugs and other unexpected issues.\r\nThe fir… [+1414 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Joe Tilleli',
#   'title': 'Anker 3-in-1 MagSafe Charger Is at Its Lowest Price, Free Adapter Included for a Limited Time',
#   'description': 'Save 29% on the Anker MagSafe charger designed for use with the Apple Watch, AirPods, and iPhone.',
#   'url': 'https://gizmodo.com/anker-3-in-1-magsafe-charger-is-at-its-lowest-price-free-adapter-included-for-a-limited-time-2000608407',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/AnkerMagsafe.jpg',
#   'publishedAt': '2025-05-29T15:10:19Z',
#   'content': 'We are inundated with devices that need to be plugged in every once in awhile. Our phones need to charge, our headphones need to charge, our watches you guessed it need to charge. This can result in … [+2222 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Cheryl Eddy',
#   'title': 'The Mule Is All the Way Here in the Full ‘Foundation’ Season 3 Trailer',
#   'description': "Apple TV+'s Isaac Asimov adaptation returns July 11, and it's bringing an intergalactic psychic villain along for the ride.",
#   'url': 'https://gizmodo.com/foundation-season-3-trailer-pilou-asbaek-lee-pace-2000613988',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Foundation-topart-1200x675.jpg',
#   'publishedAt': '2025-06-11T14:00:58Z',
#   'content': 'The full trailer for Foundationseason three is here, and while it features plenty of Lee Pace in all his Space Jesus glory, it also gives fans the best look yet at a very important character: the Mul… [+2123 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Brittany Vincent',
#   'title': 'Apple AirPods Pro 2 Are Part of a June Sale, Perfect for Father’s Day Gifting',
#   'description': "Listen to all your favorite music and podcasts with these reliable Apple buds that you won't want to take off.",
#   'url': 'https://gizmodo.com/apple-airpods-pro-2-are-part-of-a-june-sale-perfect-for-fathers-day-gifting-2000600466',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/airpodspro2.jpg',
#   'publishedAt': '2025-06-02T15:10:37Z',
#   'content': 'A new pair of earbuds may feel like a splurge, but only if you spend full price on them. The truth is, you can get an absolutely excellent pair if you know when to look and how much is fair to pay. H… [+2074 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Mike Fazioli',
#   'title': 'Apple Slashes 2024 M4 Mac Mini Price Below Black Friday, Feels Like a Surprise Clearout Sale on Amazon',
#   'description': "Apple's famous little desktop computer now comes with a huge upgrade, including iPhone mirroring and Apple Intelligence.",
#   'url': 'https://gizmodo.com/apple-slashes-2024-m4-mac-mini-price-below-black-friday-feels-like-a-surprise-clearout-sale-on-amazon-2000616685',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Mac-Mini-2024-1200x675.jpg',
#   'publishedAt': '2025-06-17T12:10:18Z',
#   'content': 'The Mac Mini blew away the computing world when it debuted in 2005 a Mac desktop computer with all of the processing power and cool features of its larger siblings, but at a fraction of the size. In … [+2209 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Cameron Faulkner',
#   'title': 'Apple CarPlay is getting widgets and message tapbacks this fall with iOS 26',
#   'description': 'Apple announced sweeping updates to iOS 26 during WWDC 25 that’ll launch this fall, and that extends to CarPlay, its infotainment interface. CarPlay and CarPlay Ultra-compatible cars will reap the benefits of the new update, both in terms of aesthetics and at…',
#   'url': 'https://www.theverge.com/news/683644/carplay-apple-ios-26-widgets-live-activities-tapbacks-wwdc-25',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/carplayiOS26.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-09T19:49:56Z',
#   'content': 'The same widgets and Live Activities that work on the iPhone will automatically work on CarPlay, too.\r\nThe same widgets and Live Activities that work on the iPhone will automatically work on CarPlay,… [+1402 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Andrew J. Hawkins',
#   'title': 'Apple will let you play video in CarPlay with iOS 26',
#   'description': 'Apple’s days of blocking you from watching video through CarPlay appear to be coming to an end. The upcoming iOS26 update will allow people to project video from their phones onto the center display of their vehicle through AirPlay. This will enable users to …',
#   'url': 'https://www.theverge.com/news/686046/apple-carplay-airplay-video-streaming-ios26',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/01/apple-carplay-review_897374.jpg?quality=90&strip=all&crop=0%2C3.4613147178592%2C100%2C93.077370564282&w=1200',
#   'publishedAt': '2025-06-12T16:21:36Z',
#   'content': 'Apple’s days of blocking you from watching video through CarPlay appear to be coming to an end. The upcoming iOS26 update will allow people to project video from their phones onto the center display … [+1931 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'James Pero',
#   'title': 'Apple Intelligence Can Now Creep on Your iPhone Screen',
#   'description': "Visual Intelligence brings Apple's AI features a little bit closer to competitors with the ability to see what you're looking at on your phone.",
#   'url': 'https://gizmodo.com/apple-intelligence-can-now-creep-on-your-iphone-screen-2000613127',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/IMG_2680-1-1200x675.jpg',
#   'publishedAt': '2025-06-09T21:01:13Z',
#   'content': 'It wouldn’t be a developer keynote in 2025 without a little AI, right? As underwhelming as Apple Intelligence has been since its rollout in October last year, Apple seems to be committed to upgrading… [+4605 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Lauren Goode',
#   'title': "OpenAI's Big Bet That Jony Ive Can Make AI Hardware Work",
#   'description': 'Io, a firm Ive and Sam Altman cocreated, will now merge with OpenAI.',
#   'url': 'https://www.wired.com/story/jony-ive-open-ai-hardware-io/',
#   'urlToImage': 'https://media.wired.com/photos/682e0aa2e697c0df119ce200/191:100/w_1280,c_limit/Jony-Ive-Business-1191537321.jpg',
#   'publishedAt': '2025-05-21T18:33:39Z',
#   'content': 'OpenAI has fully acquired Io, a joint venture it cocreated last year with Jony Ive, the famed British designer behind the sleek industrial aesthetic that defined the iPhone and more than two decades … [+3382 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'James Pero',
#   'title': 'Apple Knows AI Isn’t What People Really Want, but It Can’t Say That',
#   'description': "Apple execs didn't have a super satisfying answer about what went wrong with AI Siri, but they also don't really need one.",
#   'url': 'https://gizmodo.com/apple-knows-ai-isnt-what-people-really-want-but-it-cant-say-that-2000614436',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/wsjscreenshot-1200x675.jpg',
#   'publishedAt': '2025-06-11T17:30:30Z',
#   'content': 'If you felt like Apple’s WWDC 2025 was a bit light on AI, you’re not alone. While conferences from competitors like Google and its annual I/O keynote were basically breathless in launching new Gemini… [+4868 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'James Pero',
#   'title': 'Apple Has a Huge Siri Problem That WWDC 2025 Probably Won’t Fix',
#   'description': "If Apple is going to address its stumbles with AI, now would be the time, but my hopes aren't super high.",
#   'url': 'https://gizmodo.com/apple-has-a-huge-siri-problem-that-wwdc-2025-probably-wont-fix-2000612362',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/ios19-siri-1200x675.jpg',
#   'publishedAt': '2025-06-06T18:10:14Z',
#   'content': 'Apple’s annual WWDC developer conference is almost here, and it’s shaping up to be an important one. Not just for iOS, which is taking another step forward into a rumored redesigned iOS 19eriOS 26, o… [+4894 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Gizmodo Deals',
#   'title': 'Amid Competition, Amazon Is Clearing 2025 MacBook Air M4 Stock at an All-Time Low',
#   'description': 'There’s no reason to pay an extra $150 at the Apple Store when you can get this exact model on Amazon.',
#   'url': 'https://gizmodo.com/amid-competition-amazon-is-clearing-2025-macbook-air-m4-stock-at-an-all-time-low-2000608613',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/04/Apple2025MacBookAirM4.jpg',
#   'publishedAt': '2025-05-29T13:25:22Z',
#   'content': 'When it comes to Apple computers, the best seller is the MacBook Air (and rightfully so). These slim computers aren’t only powerful and gorgeous but they’re also priced in such a way that they remain… [+3001 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Mike Fazioli',
#   'title': 'Anker’s 3-in-1 Foldable Charging Cube Is an Apple Fan’s Must-Buy While It’s Cheaper Than Previous Prime Days',
#   'description': 'Add this cool MagSafe charger with retractable Apple Watch tray, adjustable iPhone stand, and AirPods platform to your travel bag for 25% off.',
#   'url': 'https://gizmodo.com/ankers-3-in-1-foldable-charging-cube-is-an-apple-fans-must-buy-while-its-cheaper-than-previous-prime-days-2000610510',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/Anker-Cube-1200x675.jpg',
#   'publishedAt': '2025-06-04T16:10:09Z',
#   'content': 'Three-in-one chargers for your smartphone, smartwatch, and wireless earbuds aren’t new, but their design tends to range from “a little too big” to “takes up my whole nightstand.” Not surprisingly, th… [+2584 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Is This Really Apple’s Big Plan to Make Gaming Stick?',
#   'description': "Gaming on iPhone and Mac will now go through a new 'Apple Games' app. Now it just needs games and features players actually want.",
#   'url': 'https://gizmodo.com/is-this-really-apples-big-plan-to-make-gaming-stick-2000613224',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/WWDC25-Apple-Gaming-Overlay-Mac-1-1200x675.jpg',
#   'publishedAt': '2025-06-09T20:52:35Z',
#   'content': 'Ive been writing about Apples newfound gaming ambitions\xa0for years now, but I’m still waiting for the company to come to grips with what today’s gamer actually wants. My halting enthusiasm is often te… [+5197 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Charles Pulliam-Moore',
#   'title': 'A dark power is rising in Foundation’s new season 3 trailer',
#   'description': 'The first teaser for season 3 of Apple TV Plus’ Foundation hinted at some of the changes coming with the series’ massive timeskip. But the show’s latest trailer really hammers how much wilder this story is about to get. Though Foundation‘s third season jumps …',
#   'url': 'https://www.theverge.com/news/684891/foundation-season-3-trailer-premiere-date-apple-tv-plus',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Foundation_303_F00066F.jpg?quality=90&strip=all&crop=12.497005208333%2C0%2C79.583333333333%2C100&w=1200',
#   'publishedAt': '2025-06-11T14:03:25Z',
#   'content': 'The third season of Apple TV Plus Foundation sci-fi series is set to debut on July 11th.\r\nThe third season of Apple TV Plus Foundation sci-fi series is set to debut on July 11th.\r\nThe first teaser fo… [+1124 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jennifer Pattison Tuohy',
#   'title': 'It could be 2026 before all your Thread border routers work together',
#   'description': 'There’s finally some good news for anyone battling multiple Thread networks while using Matter devices in their smart home — as long as you’re the patient type. According to Matter Alpha, the tvOS 26 beta announced at WWDC this week adds Thread 1.4 to Apple T…',
#   'url': 'https://www.theverge.com/news/686512/apple-thread-1-4-tvos-26-matter-google-amazon',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/VRG_ILLO_5281_ThreadGroup_Matter.webp?quality=90&strip=all&crop=0%2C10.330086736612%2C100%2C79.339826526775&w=1200',
#   'publishedAt': '2025-06-12T22:45:12Z',
#   'content': 'Code in tvOS 26 shows Thread 1.4 is coming to Apples border routers this fall. But with Amazon and Google still on 1.3, you may be waiting a bit longer for that unified mesh network.\r\nTheres finally … [+4385 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Ryan Waniata',
#   'title': 'Best AirPods Pro Alternatives: AirPods for Android and More',
#   'description': 'These excellent AirPod alternatives provide great features and versatility in a familiar package.',
#   'url': 'https://www.wired.com/gallery/best-airpods-alternatives/',
#   'urlToImage': 'https://media.wired.com/photos/6834c456832d0c3fb86602b0/191:100/w_2580,c_limit/Best-AirPods-Pro-Alternatives.jpg',
#   'publishedAt': '2025-05-27T12:33:00Z',
#   'content': "They're are a lot of traits that spell out Apple's most popular pair, but their conveniently grabbable, stem-style design is a good start. Most of the pairs on our list share this Apple-pioneered for… [+774 chars]"},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Zombie AI Siri May Shuffle Onto iPhones Two Years After It Was First Announced',
#   'description': 'At that point, will we even care anymore about AI Siri?',
#   'url': 'https://gizmodo.com/zombie-ai-siri-may-shuffle-onto-iphones-two-years-after-it-was-first-announced-2000615520',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/A1A9528-1200x675.jpg',
#   'publishedAt': '2025-06-13T14:30:35Z',
#   'content': 'At this weeks WWDC 2025 keynote, Apples senior vice president of software, Craig Federighi, strutted up on stage to the sound of Ratts “Round and Round” playing in the background. Lovell will find a … [+3198 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Kyle Barr',
#   'title': 'Everything We Expect Apple to Announce at WWDC25 on June 9',
#   'description': "Apple's iOS 26 (yes, you read that right) may feature the same see-through bubble UI as the rest of Apple's ecosystem.",
#   'url': 'https://gizmodo.com/everything-we-expect-apple-to-announce-at-wwdc25-on-june-9-2000611326',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/DSCF1401-2-1200x675.jpg',
#   'publishedAt': '2025-06-04T20:20:35Z',
#   'content': 'Apple is planning to completely rejigger the software on all its biggest products, from the iPhone and Mac all the way down to the Vision Pro. To promote this rapid maturation across the Apple ecosys… [+5006 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'James Pero',
#   'title': 'With AI Siri Delayed, Apple’s AirPods Pro 3 May Be Next',
#   'description': 'Do AirPods Pro have a Siri problem, too?',
#   'url': 'https://gizmodo.com/with-ai-siri-delayed-apples-airpods-pro-3-may-be-next-2000616296',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/AirPods-2-1200x675.jpg',
#   'publishedAt': '2025-06-16T21:30:56Z',
#   'content': 'If you were itching for a new pair of AirPods Pro, you may want to clip those fingernails because that itch could persist for another year. According to yet another Apple analyst, the AirPods Pro 3 m… [+3188 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Emma Roth',
#   'title': 'Garmin’s Venu X1 smartwatch has its biggest display and smallest case yet',
#   'description': 'Garmin announced the $799 Venu X1 fitness watch today. It offers a\xa0 2-inch square AMOLED screen and seems like a shot at the Apple Watch Ultra 2, given its similar square design and titanium body, even though the company’s other watches already offer similar …',
#   'url': 'https://www.theverge.com/news/686325/garmin-venu-x1-smartwatch-display-specs-pricing',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/Venu_X1.webp?quality=90&strip=all&crop=0%2C12.306680387035%2C100%2C75.38663922593&w=1200',
#   'publishedAt': '2025-06-12T18:19:08Z',
#   'content': 'With a 2-inch, squared-off display, Garmins $799.99 smartwatch looks like a direct competitor to the Apple Watch Ultra 2.\r\nWith a 2-inch, squared-off display, Garmins $799.99 smartwatch looks like a … [+1393 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Umar Shakir',
#   'title': 'Google starts beta testing Android 16’s youthful new look',
#   'description': 'Google has announced its rolling out the colorful new Android 16 interface for beta testers as reported by 9to5Google. The QPR1 beta includes the company’s Material 3 Expressive design language revealed officially last week and includes new visuals for the la…',
#   'url': 'https://www.theverge.com/news/671153/google-beta-android-16-material-3-expressive-design-roll-out',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/google-material-3-expressive.png?quality=90&strip=all&crop=0%2C17.551211355085%2C100%2C64.897577289829&w=1200',
#   'publishedAt': '2025-05-20T21:05:57Z',
#   'content': 'Enrolled and eligible Pixel devices can try out the vibrant Material 3 Expressive design early.\r\nEnrolled and eligible Pixel devices can try out the vibrant Material 3 Expressive design early.\r\nGoogl… [+1690 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'OpenAI is buying Jony Ive’s AI hardware company',
#   'description': 'OpenAI is buying io, a hardware company founded by former Apple design chief Jony Ive and several other former engineers from his time there, including Scott Cannon, Evans Hankey, and Tang Tan. “We gathered together the best hardware and software engineers, t…',
#   'url': 'https://www.theverge.com/news/671838/openai-jony-ive-ai-hardware-apple',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/portrait-3.jpg?quality=90&strip=all&crop=0,15.095986038394,100,69.808027923211',
#   'publishedAt': '2025-05-21T17:21:09Z',
#   'content': 'The deal is valued at nearly $6.5 billion.\r\nThe deal is valued at nearly $6.5 billion.\r\nOpenAI is buying io, a hardware company founded by former Apple design chief Jony Ive and several other former … [+818 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Brandon Widder',
#   'title': 'Apple’s latest AirPods Pro with USB-C just received a $70 discount',
#   'description': 'This year’s WWDC kicks off in less than a week, which means Apple is likely to announce a string of software changes in short order, some of which are designed to improve Apple’s latest pair of premium earbuds. Thankfully, if you haven’t yet pulled the trigge…',
#   'url': 'https://www.theverge.com/tech/681365/apple-airpods-2-usb-c-meta-quest-3s-deal-sale',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/AirPods-Pro-USB-C-Deal-Image.png?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-07T14:10:47Z',
#   'content': 'Plus, you can save on Metas excellent Quest 3S headset and a dirt-cheap location tracker.\r\nPlus, you can save on Metas excellent Quest 3S headset and a dirt-cheap location tracker.\r\nThis years WWDC k… [+3136 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Barbara Krasnoff',
#   'title': 'How to install the iOS 26 and iPadOS 26 developer betas',
#   'description': "The most recent presentation of Apple's WWDC event has come and gone, during which Apple introduced the developer beta of the newly renamed iOS 26 - which is accessible to everyone, non-developers included, for free. If you want to try out an early version of…",
#   'url': 'https://www.theverge.com/684487/ios-ipados-26-install-developer-how-to',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/How_to_IOS_26_install.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-11T15:24:29Z',
#   'content': 'Developer betas are now available to everyone, free of charge and easy to install. But think twice before you enable it on your day-to-day phone.\r\nThe most recent presentation of Apples WWDC event ha… [+3521 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jay Peters',
#   'title': 'Tim Sweeney didn’t expect a five-year Fortnite ban',
#   'description': 'Fortnite was missing from the iOS App Store for nearly five years before returning to the US last month. Apple kicked the game off in 2020 after Epic snuck in an in-app payment mechanism that violated App Store rules at the time. Epic CEO Tim Sweeney knew tha…',
#   'url': 'https://www.theverge.com/games/678885/epic-games-ceo-tim-sweeney-five-year-fortnite-ban',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23951570/VRG_Illo_STK186_L_Normand_TimSweeney_Neutral.jpg?quality=90&strip=all&crop=0%2C0%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-06-03T18:05:15Z',
#   'content': 'He hoped the game would only be off the App Store for a few weeks.\r\nHe hoped the game would only be off the App Store for a few weeks.\r\nFortnite was missing from the iOS App Store for nearly five yea… [+2817 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'David Pierce',
#   'title': 'Hang on, did the iPad just become a computer?',
#   'description': "I genuinely never expected to say this: it appears Apple finally figured out multitasking on the iPad. With iPadOS 26, the company hasn't completely taken off the guardrails for how you can use and place apps on your tablet, but it came awfully close. With a …",
#   'url': 'https://www.theverge.com/ipad/684229/ipados-26-hands-on-multitasking-mac',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/06/IMG_0005.jpeg?quality=90&strip=all&crop=0%2C12.329204443877%2C100%2C75.341591112246&w=1200',
#   'publishedAt': '2025-06-10T13:22:20Z',
#   'content': 'Hang on, did the iPad just become a computer?\r\nApple wont give us a Mac-powered tablet. But it may have finally done the next best thing.\r\nHang on, did the iPad just become a computer?\r\nApple wont gi… [+6030 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Charles Pulliam-Moore',
#   'title': 'Netflix’s series about the FTX fiasco has found its leading effective altruists',
#   'description': 'Like Amazon and Apple, Netflix is also looking to cash in on the story of how Sam Bankman-Fried and Caroline Ellison managed to steal billions from the FTX cryptocurrency exchange. Variety reports that Anthony Boyle (Tetris, Manhunt) and Julia Garner (Ozark, …',
#   'url': 'https://www.theverge.com/news/676726/netflix-the-altruists-casting-ftx-sam-bankman-fried-caroline-ellison',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/gettyimages-2213953425.jpg?quality=90&strip=all&crop=0%2C9.633208664368%2C100%2C34.921614187022&w=1200',
#   'publishedAt': '2025-05-29T21:06:11Z',
#   'content': 'The Altruists has cast Anthony Boyle as Sam Bankman-Fried and Julia Garner as Caroline Ellison.\r\nThe Altruists has cast Anthony Boyle as Sam Bankman-Fried and Julia Garner as Caroline Ellison.\r\nLike … [+1621 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Vanessa Taylor',
#   'title': 'Trump Threatens His ‘Friend’ Tim Cook With 25% iPhone Tariff If Apple Doesn’t Move Production to U.S.',
#   'description': 'A series of shifting and often contradictory tariff policies have left a mess in their wake. Will Trump actually stick to this threat?',
#   'url': 'https://gizmodo.com/trump-threatens-apple-with-25-tariff-on-iphones-produced-outside-the-u-s-2000606513',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2024/03/ac7cfd0a81178a3fcc18371e05e707e9.jpg',
#   'publishedAt': '2025-05-23T17:39:27Z',
#   'content': 'President Donald Trump’s desire to create a golden age of American manufacturing is at the center of his trade warfeasibility be damnedand not even his friends can get around it. On Friday, Trump thr… [+3494 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'Apple Stops Work on Camera-Equipped Apple Watch Planned for 2027',
#   'description': "Apple is no longer planning to release an Apple Watch that includes a camera, reports Bloomberg. Apple was developing Apple Watch and Apple Watch Ultra models that had a camera to view the wearer's surrounding environment, but work on those projects ended thi…",
# ...
#   'url': 'https://www.macrumors.com/2025/06/10/ios-26-wallet-app-package-tracking/',
#   'urlToImage': 'https://images.macrumors.com/t/NSdL2L4ChmUWxSs8fuRo7VF-D9Y=/2000x/article-new/2025/06/ios-26-wallet-order-tracking.jpg',
#   'publishedAt': '2025-06-10T23:09:14Z',
#   'content': 'Apple is integrating Apple Intelligence in the Wallet app in iOS 26, with the aim of powering a new package tracking feature. Apple Wallet will be able to automatically scan your emails to find messa… [+895 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Gizmodo Deals',
#   'title': 'Forget The Apple Watch at Full Price, Our Favorite Galaxy Watch Ultra Is Now 40% Off on Amazon',
#   'description': 'This is the all-time low price for the best sports smartwatch on Android.',
#   'url': 'https://gizmodo.com/forget-the-apple-watch-at-full-price-our-favorite-galaxy-watch-ultra-is-now-40-off-on-amazon-2000612954',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2024/11/galaxy-watch-ultra.jpg',
#   'publishedAt': '2025-06-08T14:28:17Z',
#   'content': 'The\xa0Galaxy Watch Ultra is the top of the line for Samsung’s smartwatch lineup with high-end features that put it on the level with Apple Watch Ultra. Designed for serious athletes and technophiles, i… [+2128 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Joe Tilleli',
#   'title': 'Apple MacBook Pro 13″ With Touch Bar Price Is Almost Nothing, This 77% Off Grade-A Refurb Deal Ends Soon',
#   'description': 'Save over a thousand bucks on this StackSocial deal for a Grade-A refurbished MacBook Pro.',
#   'url': 'https://gizmodo.com/apple-macbook-pro-13-with-touch-bar-price-is-almost-nothing-this-77-off-grade-a-refurb-deal-ends-soon-2000613896',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/AppleMacBookTouchbar2017-1200x675.jpg',
#   'publishedAt': '2025-06-11T15:10:31Z',
#   'content': 'Looking to replace you laptop but dont feel like shelling out thousands for the latest MacBook? Well you dont need to sweat. You can grab yourself something perfectly capable of meeting your everyday… [+2172 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Gizmodo Deals',
#   'title': 'Apple Quality at a Lower Price, Amazon Crushes iPad 2025 Prices to a New All-Time Low',
#   'description': 'Thanks to this discount, the iPad 2025 is almost as affordable as many of the basic tablets offered by rival brands.',
#   'url': 'https://gizmodo.com/apple-quality-at-a-lower-price-amazon-crushes-ipad-2025-prices-to-a-new-all-time-low-2000609884',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/05/A16-iPad.jpg',
#   'publishedAt': '2025-06-02T11:10:57Z',
#   'content': 'Apple’s reputation for making the best-of-the-best devices is well deserved. iPhones, iPads, Watches and MacBooks set the benchmark by which everything else is measured within their particular market… [+2331 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Brittany Vincent',
#   'title': 'Beats Studio Buds From Apple Are at Their Lowest Price and Cheaper Than AirPods, but Stock Is Limited',
#   'description': 'Upgrade your listening experience with these discounted Beats buds and hear your music in a new way.',
#   'url': 'https://gizmodo.com/beats-studio-buds-from-apple-are-at-their-lowest-price-and-cheaper-than-airpods-but-stock-is-limited-2000612141',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/beatstudiobuds-1200x675.jpg',
#   'publishedAt': '2025-06-06T16:40:21Z',
#   'content': 'Music is one of the greatest pleasures that you can enjoy for free, for the most part. When you hear your favorite song, you come alive. And it’s one of the most universal ways to communicate. So you… [+2171 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Joe Tilleli',
#   'title': 'Google Pixel Buds Drop to Practically Free Compared to Apple AirPods, Limited Stock Won’t Wait for You',
#   'description': 'Save $0 on the Google Pixel Buds wireless earbuds for a limited time at Amazon.',
#   'url': 'https://gizmodo.com/google-pixel-buds-drop-to-practically-free-compared-to-apple-airpods-limited-stock-wont-wait-for-you-2000611450',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2025/06/GooglePixelBuds-1200x675.jpg',
#   'publishedAt': '2025-06-05T13:40:15Z',
#   'content': 'Noise-cancellation is a great addition on any premium pair of headphones or earbuds, but what it does is drive up the price way high. Its not something thats always needed. If youre not frequently ri… [+2122 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Mitchel Broussard',
#   'title': 'Memorial Day Apple Deals Include Low Prices on AirPods, Apple Watch, iPad, and More',
#   'description': "Amazon is hosting a big collection of discounts across multiple Apple products this week, including notable deals on AirPods, Apple Watch, iPad, Apple Pencil Pro, and MacBook Air. We're also still tracking great Memorial Day discounts across popular brands li…",
#   'url': 'https://www.macrumors.com/2025/05/26/memorial-day-apple-deals-2025/',
#   'urlToImage': 'https://images.macrumors.com/t/kabhOguRlXrbMLKwi_R45ByEZiM=/2500x/article-new/2022/05/memorial-day-2022-feature.jpg',
#   'publishedAt': '2025-05-26T16:07:51Z',
#   'content': "Amazon is hosting a big collection of discounts across multiple Apple products this week, including notable deals on AirPods, Apple Watch, iPad, Apple Pencil Pro, and MacBook Air. We're also still tr… [+2710 chars]"},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Tim Hardwick',
#   'title': 'Apple Watch Ultra 3 Finally Coming After Two-Year Hiatus',
#   'description': 'Apple will finally deliver the Apple Watch Ultra 3 sometime this year, according to analyst Jeff Pu of GF Securities Hong Kong (via @jukanlosreve). \n\n\n\n\n\nThe analyst expects both the Apple Watch Series 11 and Apple Watch Ultra 3 to arrive this year (likely al…',
#   'url': 'https://www.macrumors.com/2025/06/16/apple-watch-ultra-3-finally-coming-2025/',
#   'urlToImage': 'https://images.macrumors.com/t/P4LdECugnko3tpuGqLbffEs9dJ0=/2500x/article-new/2024/09/apple-watch-ultra-2-new-black.jpg',
#   'publishedAt': '2025-06-16T15:45:00Z',
#   'content': 'Apple will finally deliver the Apple Watch Ultra 3 sometime this year, according to analyst Jeff Pu of GF Securities Hong Kong (via @jukanlosreve). \r\nThe analyst expects both the Apple Watch Series 1… [+1362 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Wes Davis',
#   'title': 'Android Auto will get Spotify Jam and support for video apps and web browsers',
#   'description': 'Android Auto is getting more than just Google’s Gemini assistant after the Google I/O developer conference. The company has also announced or otherwise shown off a slew of changes coming to the infotainment operating system, including an updated Spotify app, …',
#   'url': 'https://www.theverge.com/news/674126/android-auto-spotify-jam-web-browsers-video-apps',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2025/05/Spotify-Jam.png?quality=90&strip=all&crop=0%2C10.742998834307%2C100%2C78.514002331385&w=1200',
#   'publishedAt': '2025-05-25T16:55:38Z',
#   'content': 'Last week, Google revealed a lot of changes coming to Android Auto.\r\nLast week, Google revealed a lot of changes coming to Android Auto.\r\nAndroid Auto is getting more than just Googles Gemini assista… [+2263 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': "Apple Shares WWDC 2025 Playlist With One Hour of 'Summer Sounds'",
#   'description': 'Looking forward to WWDC 2025? Get in the mood with the official Apple Music playlist for the event, which features 20 songs from a variety of artists, including Benson Boone, Charli xcx, Ed Sheeran, Don Toliver, and others.\n\n\n\n\n\n"Get ready for the biggest App…',
#   'url': 'https://www.macrumors.com/2025/06/03/apple-shares-wwdc-2025-playlist/',
#   'urlToImage': 'https://images.macrumors.com/t/jsPQQ5G0NoXbzWGtIGZdKffj8ak=/1600x/article-new/2025/06/WWDC-2025-YouTube-Thumbnail.jpg',
#   'publishedAt': '2025-06-03T17:28:57Z',
#   'content': 'Looking forward to WWDC 2025? Get in the mood with the official Apple Music playlist for the event, which features 20 songs from a variety of artists, including Benson Boone, Charli xcx, Ed Sheeran, … [+413 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'watchOS 26 Removes These Apple Watch Faces',
#   'description': 'Apple has removed several Apple Watch faces that are options in watchOS 11, nixing the Fire/Water, Gradient, Liquid Metal, Vapor, and Toy Story watch faces, according to a post on Reddit.\n\n\n\n\n\nApple tends to quietly remove some watch face options when it laun…',
#   'url': 'https://www.macrumors.com/2025/06/10/watchos-26-removes-these-apple-watch-faces/',
#   'urlToImage': 'https://images.macrumors.com/t/MRrekiS9uXT5weoZjYS8WLyB2VU=/1865x/article-new/2025/06/watchos-26.jpg',
#   'publishedAt': '2025-06-10T20:30:24Z',
#   'content': 'Apple has removed several Apple Watch faces that are options in watchOS 11, nixing the Fire/Water, Gradient, Liquid Metal, Vapor, and Toy Story watch faces, according to a post on Reddit.\r\nApple tend… [+371 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': 'Apple Store in the Netherlands Temporarily Closing Starting Next Month',
#   'description': 'Apple has announced that its Den Haag store in the Netherlands will be temporarily closed for renovations starting this Sunday, June 1.\n\n\n\n\n\nThe store is located in The Hague, the capital city of South Holland.\n\n\n\nFirst opened in 2014, Apple De Haag is one of…',
#   'url': 'https://www.macrumors.com/2025/05/29/apple-den-haag-temporarily-closing/',
#   'urlToImage': 'https://images.macrumors.com/t/oq-fLdoBiLT46iN0BLKD-KONi8w=/2880x/article-new/2025/05/Apple-Store-Den-Haag.jpeg',
#   'publishedAt': '2025-05-29T20:42:03Z',
#   'content': 'Apple has announced that its Den Haag store in the Netherlands will be temporarily closed for renovations starting this Sunday, June 1.\r\nThe store is located in The Hague, the capital city of South H… [+449 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Juli Clover',
#   'title': 'WWDC 2025: New Features We Could See in watchOS 26',
#   'description': "We're still counting down the days until the 2025 Worldwide Developers Conference, and Apple's big event is creeping closer. We haven't heard too much about what we might see in watchOS 26, but there are a few hints based on rumors, info about other updates, …",
#   'url': 'https://www.macrumors.com/2025/06/04/wwdc-2025-watchos-26/',
#   'urlToImage': 'https://images.macrumors.com/t/Z3Wwi6EGQDKLMGy1XNVFiZ7d37s=/2500x/article-new/2025/05/watchOS-26-Mock-Feature.jpg',
#   'publishedAt': '2025-06-04T23:00:37Z',
#   'content': "We're still counting down the days until the 2025 Worldwide Developers Conference, and Apple's big event is creeping closer. We haven't heard too much about what we might see in watchOS 26, but there… [+4745 chars]"},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Macy Meyer',
#   'title': "iPhone's Phone App Is Getting a Major Upgrade, Including a Smarter Way to Wait on Hold",
#   'description': 'Apple is finally upgrading the Phone app.',
#   'url': 'https://www.cnet.com/tech/mobile/iphones-phone-app-is-getting-a-major-upgrade-including-a-smarter-way-to-wait-on-hold/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/fbd77a3b4d2e110421a63d8fbc92fafa9921cd08/hub/2025/06/09/4b991b37-1f6d-4db2-a85e-102a78582f8f/screenshot-2025-06-09-at-1-23-33pm.png?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2025-06-09T17:57:00Z',
#   'content': "Apple's Phone app is finally getting a major glow-up. If you've ever been stuck on hold with customer service, you'll appreciate one of the biggest changes coming with iOS 26.\r\nAt its WWDC 2025 keyno… [+1954 chars]"},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Alex Heath',
#   'title': 'OpenAI wants ChatGPT to be a ‘super assistant’ for every part of your life',
#   'description': 'Thanks to the legal discovery process, Google\'s antitrust trial with the Department of Justice has provided a fascinating glimpse into the future of ChatGPT. An internal OpenAI strategy document titled "ChatGPT: H1 2025 Strategy" describes the company\'s aspir…',
#   'url': 'https://www.theverge.com/command-line-newsletter/677705/openai-chatgpt-super-assistant',
#   'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/25461999/STK155_OPEN_AI_CVirginia_A.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200',
#   'publishedAt': '2025-05-30T23:18:26Z',
#   'content': 'An internal strategy document lays out OpenAIs ambition to build your interface to the internet.\r\nAn internal strategy document lays out OpenAIs ambition to build your interface to the internet.\r\nTha… [+7450 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': 'Apple TV+ Announces MLB Friday Night Baseball Schedule for July',
#   'description': 'Apple and Major League Baseball this week announced the July schedule for Friday Night Baseball, a weekly doubleheader of MLB games streamed on Apple TV+.\n\n\n\n\n\nFriday Night Baseball is included with an Apple TV+ subscription, at no additional cost. In the U.S…',
#   'url': 'https://www.macrumors.com/2025/06/06/apple-friday-night-baseball-july-schedule/',
#   'urlToImage': 'https://images.macrumors.com/t/wlNIDxVqRPoiQ6Frx5G6wrPM5jY=/1960x/article-new/2025/06/MLB-Friday-Night-Baseball-Feature.jpg',
#   'publishedAt': '2025-06-06T17:24:59Z',
#   'content': 'Apple and Major League Baseball this week announced the July schedule for Friday Night Baseball, a weekly doubleheader of MLB games streamed on Apple TV+.\r\nFriday Night Baseball is included with an A… [+762 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': "Take a Break From WWDC 2025 With Apple's Chill Coffee Shop Playlist",
#   'description': "It is day four of WWDC 2025 week, and the dust is finally beginning to settle. Whether you are an Apple fan who has been keeping up with the avalanche of news, or a developer who has been scrolling through all of Apple's latest documentation, it has been a wh…",
#   'url': 'https://www.macrumors.com/2025/06/12/wwdc-2025-coffee-shop-playlist/',
#   'urlToImage': 'https://images.macrumors.com/t/jsPQQ5G0NoXbzWGtIGZdKffj8ak=/1600x/article-new/2025/06/WWDC-2025-YouTube-Thumbnail.jpg',
#   'publishedAt': '2025-06-12T19:20:46Z',
#   'content': 'It is day four of WWDC 2025 week, and the dust is finally beginning to settle. Whether you are an Apple fan who has been keeping up with the avalanche of news, or a developer who has been scrolling t… [+410 chars]'},
#  {'source': {'id': None, 'name': 'MacRumors'},
#   'author': 'Joe Rossignol',
#   'title': 'Apple Store With Updated Design Opening in Arizona Later This Week',
#   'description': "Apple recently announced that it will be opening a freshly remodeled store at La Encantada in Tucson, Arizona, on Saturday, June 14.\n\n\n\n\n\nThe grand re-opening will take place at 10 a.m. local time:We're making moves. Come with us. Apple La Encantada opens Jun…",
#   'url': 'https://www.macrumors.com/2025/06/09/apple-store-updated-design-arizona/',
#   'urlToImage': 'https://images.macrumors.com/t/G87q6Sdfxb-VKyDAmgaltn2wINI=/1600x/article-new/2025/01/iPhone-16-Apple-Store-Levels.jpg',
#   'publishedAt': '2025-06-09T12:55:44Z',
#   'content': "Apple recently announced that it will be opening a freshly remodeled store at La Encantada in Tucson, Arizona, on Saturday, June 14.\r\nThe grand re-opening will take place at 10 a.m. local time:\r\nWe'r… [+355 chars]"}]

# %%
dataset = []
counter = 0
for idx, article in enumerate(all_articles['articles']):
  url = article["url"]
  try:
    response = requests.get(url, headers = {'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(response.text, "html.parser")

    paragrapgs = soup.find_all("p")
    content = "\n".join([p.text for p in paragrapgs])

  except Exception as e:
    content = f"ERROR: {e}"

  dataset.append({
      "index": idx,
      "population_date" : article["publishedAt"].split("T")[0],
      "source" : article["source"]["name"],
      "author" : article["author"],
      "title" : article["title"],
      "content" : content
  })
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#    index population_date     source                 author  \
# 0      0      2025-06-09  The Verge             Jay Peters
# 1      1      2025-05-28  The Verge        Dominic Preston
# 2      2      2025-05-27  The Verge  Wes Davis, Jay Peters
# 3      3      2025-06-09  The Verge              Emma Roth
# 4      4      2025-06-12  The Verge             Jay Peters
#
#                                                title  \
# 0  Apple’s new Games app lets you challenge your ...
# 1        Apple’s DIY repair program now covers iPads
# 2  Apple is ready to replace Game Center with a m...
# 3      Apple WWDC 2025: the 13 biggest announcements
# 4  Apple’s upgraded Siri might not arrive until n...
#
#                                              content
# 0  Another gaming initiative from Apple that’s me...
# 1  Recent iPad, mini, Air, and Pro models are now...
# 2  The company has also acquired RAC7, the develo...
# 3  Big changes are in store across Apple’s platfo...
# 4  ﻿It could launch with iOS 26.4.\n﻿It could lau...

# %%
hatali_satirlar = df[df['content'].str.startswith('ERROR:')]
print(f"Number of incorrect content: {len(hatali_satirlar)}")
# Out:
# Number of incorrect content: 0

# %% [markdown]
# ## News Sentiment
# In this chapter, I will sentiment the news dataset. I will use the ProsusAI/finbert llm model at the Huggingface for sentiment news data.

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert").to(device)
labels = ["positive", "negative", "neutral"]
# Out:
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
def estimate_sentiment(news):
    if news:
        tokens = tokenizer(news, return_tensors="pt", padding=True, truncation = True).to(device)

        result = model(tokens["input_ids"], attention_mask=tokens["attention_mask"])[
            "logits"
        ]
        result = torch.nn.functional.softmax(torch.sum(result, 0), dim=-1)
        probability = result[torch.argmax(result)]
        sentiment = labels[torch.argmax(result)]
        return probability, sentiment
    else:
        return 0, labels[-1]

# %%
for idx, row in df.iterrows():
  probability, sentiment = estimate_sentiment(row["content"])
  df.loc[idx, "probability"] = probability.item()
  df.loc[idx, "sentiment"] = sentiment

# %%
df.head()
# Out:
#    index population_date     source                 author  \
# 0      0      2025-06-09  The Verge             Jay Peters
# 1      1      2025-05-28  The Verge        Dominic Preston
# 2      2      2025-05-27  The Verge  Wes Davis, Jay Peters
# 3      3      2025-06-09  The Verge              Emma Roth
# 4      4      2025-06-12  The Verge             Jay Peters
#
#                                                title  \
# 0  Apple’s new Games app lets you challenge your ...
# 1        Apple’s DIY repair program now covers iPads
# 2  Apple is ready to replace Game Center with a m...
# 3      Apple WWDC 2025: the 13 biggest announcements
# 4  Apple’s upgraded Siri might not arrive until n...
#
#                                              content  probability sentiment
# 0  Another gaming initiative from Apple that’s me...     0.901312   neutral
# 1  Recent iPad, mini, Air, and Pro models are now...     0.934646   neutral
# 2  The company has also acquired RAC7, the develo...     0.935417   neutral
# 3  Big changes are in store across Apple’s platfo...     0.893284   neutral
# 4  ﻿It could launch with iOS 26.4.\n﻿It could lau...     0.931718   neutral

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# neutral     96
# negative     4
# Name: count, dtype: int64

# %% [markdown]
# There is no positive news in these news data.

# %% [markdown]
# # Apple Stock Data
# In this chapter, I will prepare apple stock dataset.

# %%
end_day = datetime.today() - timedelta(days=1)          # Dün
start_day = end_day - timedelta(days=365)               # 1 yıl önce

# Yıl-Ay-Gün formatında string'e çevir
start_day_str = start_day.strftime('%Y-%m-%d')
end_day_str = end_day.strftime('%Y-%m-%d')

print("One year ago:", start_day_str)
print("Yesterday:", end_day_str)
# Out:
# One year ago: 2024-06-17
# Yesterday: 2025-06-17

# %%
apple = yf.Ticker("AAPL")

hist = apple.history(start=start_day_str, end=end_day_str, interval="1d")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-06-17 00:00:00-04:00  212.376781  217.930808  211.729813  215.661423
# 2024-06-18 00:00:00-04:00  216.577122  217.612289  212.008492  213.292480
# 2024-06-20 00:00:00-04:00  212.934166  213.242735  207.877826  208.703949
# 2024-06-21 00:00:00-04:00  209.410665  210.903682  206.145934  206.524170
# 2024-06-24 00:00:00-04:00  206.753084  211.709899  205.628339  207.171127
# ...                               ...         ...         ...         ...
# 2025-06-10 00:00:00-04:00  200.600006  204.350006  200.570007  202.669998
# 2025-06-11 00:00:00-04:00  203.500000  204.500000  198.410004  198.779999
# 2025-06-12 00:00:00-04:00  199.080002  199.679993  197.360001  199.199997
# 2025-06-13 00:00:00-04:00  199.729996  200.369995  195.699997  196.449997
# 2025-06-16 00:00:00-04:00  197.300003  198.690002  196.559998  198.419998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-06-17 00:00:00-04:00   93728300        0.0           0.0
# 2024-06-18 00:00:00-04:00   79943300        0.0           0.0
# 2024-06-20 00:00:00-04:00   86172500        0.0           0.0
# 2024-06-21 00:00:00-04:00  246421400        0.0           0.0
# 2024-06-24 00:00:00-04:00   80727000        0.0           0.0
# ...                              ...        ...           ...
# 2025-06-10 00:00:00-04:00   54672600        0.0           0.0
# 2025-06-11 00:00:00-04:00   60989900        0.0           0.0
# 2025-06-12 00:00:00-04:00   43904600        0.0           0.0
# 2025-06-13 00:00:00-04:00   51447300        0.0           0.0
# 2025-06-16 00:00:00-04:00   43020700        0.0           0.0
#
# [250 rows x 7 columns]

# %%
hist.reset_index(inplace = True)
hist.drop(columns=["Dividends", "Stock Splits"], inplace=True)

# %%
hist
# Out:
#                          Date        Open        High         Low       Close  \
# 0   2024-06-17 00:00:00-04:00  212.376781  217.930808  211.729813  215.661423
# 1   2024-06-18 00:00:00-04:00  216.577122  217.612289  212.008492  213.292480
# 2   2024-06-20 00:00:00-04:00  212.934166  213.242735  207.877826  208.703949
# 3   2024-06-21 00:00:00-04:00  209.410665  210.903682  206.145934  206.524170
# 4   2024-06-24 00:00:00-04:00  206.753084  211.709899  205.628339  207.171127
# ..                        ...         ...         ...         ...         ...
# 245 2025-06-10 00:00:00-04:00  200.600006  204.350006  200.570007  202.669998
# 246 2025-06-11 00:00:00-04:00  203.500000  204.500000  198.410004  198.779999
# 247 2025-06-12 00:00:00-04:00  199.080002  199.679993  197.360001  199.199997
# 248 2025-06-13 00:00:00-04:00  199.729996  200.369995  195.699997  196.449997
# 249 2025-06-16 00:00:00-04:00  197.300003  198.690002  196.559998  198.419998
#
#         Volume
# 0     93728300
# 1     79943300
# 2     86172500
# 3    246421400
# 4     80727000
# ..         ...
# 245   54672600
# 246   60989900
# 247   43904600
# 248   51447300
# 249   43020700
#
# [250 rows x 6 columns]

# %% [markdown]
# # AI Asisstant
# In this chapter, I will prepare AI assistant. This assistant will use GPT-4o-mini.

# %% [markdown]
# ## News Data Prepare For model
# In this chapter, I will delete some columns. Because If there is so much data for the LLM model.

# %%
df
# Out:
#     index population_date     source                 author  \
# 0       0      2025-06-09  The Verge             Jay Peters
# 1       1      2025-05-28  The Verge        Dominic Preston
# 2       2      2025-05-27  The Verge  Wes Davis, Jay Peters
# 3       3      2025-06-09  The Verge              Emma Roth
# 4       4      2025-06-12  The Verge             Jay Peters
# ..    ...             ...        ...                    ...
# 95     95      2025-06-09       CNET             Macy Meyer
# 96     96      2025-05-30  The Verge             Alex Heath
# 97     97      2025-06-06  MacRumors          Joe Rossignol
# 98     98      2025-06-12  MacRumors          Joe Rossignol
# 99     99      2025-06-09  MacRumors          Joe Rossignol
#
#                                                 title  \
# 0   Apple’s new Games app lets you challenge your ...
# 1         Apple’s DIY repair program now covers iPads
# 2   Apple is ready to replace Game Center with a m...
# 3       Apple WWDC 2025: the 13 biggest announcements
# 4   Apple’s upgraded Siri might not arrive until n...
# ..                                                ...
# 95  iPhone's Phone App Is Getting a Major Upgrade,...
# 96  OpenAI wants ChatGPT to be a ‘super assistant’...
# 97  Apple TV+ Announces MLB Friday Night Baseball ...
# 98  Take a Break From WWDC 2025 With Apple's Chill...
# 99  Apple Store With Updated Design Opening in Ari...
#
#                                               content  probability sentiment
# 0   Another gaming initiative from Apple that’s me...     0.901312   neutral
# 1   Recent iPad, mini, Air, and Pro models are now...     0.934646   neutral
# 2   The company has also acquired RAC7, the develo...     0.935417   neutral
# 3   Big changes are in store across Apple’s platfo...     0.893284   neutral
# 4   ﻿It could launch with iOS 26.4.\n﻿It could lau...     0.931718   neutral
# ..                                                ...          ...       ...
# 95  \n    Apple is finally upgrading the Phone app...     0.826602   neutral
# 96  An internal strategy document lays out OpenAI’...     0.906583   neutral
# 97  Apple and Major League Baseball this week anno...     0.914831   neutral
# 98  It is day four of WWDC 2025 week, and the dust...     0.921819   neutral
# 99  Apple recently announced that it will be openi...     0.900081   neutral
#
# [100 rows x 8 columns]

# %%
df.drop(columns=["index", "content", "probability"], inplace = True)

# %%
df.head()
# Out:
#   population_date     source                 author  \
# 0      2025-06-09  The Verge             Jay Peters
# 1      2025-05-28  The Verge        Dominic Preston
# 2      2025-05-27  The Verge  Wes Davis, Jay Peters
# 3      2025-06-09  The Verge              Emma Roth
# 4      2025-06-12  The Verge             Jay Peters
#
#                                                title sentiment
# 0  Apple’s new Games app lets you challenge your ...   neutral
# 1        Apple’s DIY repair program now covers iPads   neutral
# 2  Apple is ready to replace Game Center with a m...   neutral
# 3      Apple WWDC 2025: the 13 biggest announcements   neutral
# 4  Apple’s upgraded Siri might not arrive until n...   neutral

# %% [markdown]
# ## AI Asisstant

# %%
# Import GPT-4o-mini model from Openai, I use my API key in this code block
openai_api_key = userdata.get("OPENAI_API_KEY")

openai = OpenAI(api_key = openai_api_key)

OPENAI_MODEL = "gpt-4o"

# %%
news_data_information = """
news_data columns infomation:
population_date : Data of news
source : Source of the news shared
author : Author of the news
title : headline of the news
content : Content of the news
sentiment : sentiment analysis result of the news. News sentiment classes are "positive", "negative", "neutral".
"""

# %%
hist_data_information = """
Apple Stock price data columns infomation:
Date: The trading date of the stock (typically in YYYY-MM-DD format).
Open: The price at which the stock first traded when the market opened on that day.
High: The highest price at which the stock was traded during the day.
Low: The lowest price at which the stock was traded during the day.
Close: The final price at which the stock was traded when the market closed.
Volume: The total number of shares traded on that particular day.
"""

# %%
# System prompt for my llm model
system_prompt = """You are a financial time series prediction assistant. Your task is to analyze and use both quantitative stock data and qualitative news content to forecast the next 14 days of Apple Inc.'s closing stock prices.

You are provided with:

Historical stock data for Apple Inc., including daily values such as open, high, low, close, volume, and adjusted versions of these metrics. This data spans the past year.

News data, containing headlines, summaries, or full-text articles, each tagged with a date. The news content may include economic indicators, company-specific announcements, geopolitical events, or other relevant sentiment-rich information.

Instructions:

Correlate the stock market movements with related news events. Consider market sentiment, major events, and timing.

Use recent patterns from the stock data and the tone of the latest news to estimate future behavior.

Focus your prediction on the close price.

Your prediction horizon is 14 consecutive trading days after the latest date in the provided datasets.

If relevant, you may apply time series reasoning, pattern recognition, or natural language sentiment inference.

Your output must be a list or table of 14 dates with their corresponding predicted close prices.\n
"""

# %%
# User prompt funtion for create am user prompt
def user_prompt(news_data, apple_hist_data):
    # İlk birkaç satırı örneklemek
    news_sample = news_data.to_string(index=False)
    stock_sample = apple_hist_data.to_string(index=False)

    prompt = f"""
You are provided with two pandas DataFrames for predicting Apple's future stock prices.

1. `apple_hist_data`: Historical daily stock data for Apple Inc. over the past year.
It includes columns like:
{', '.join(apple_hist_data.columns.tolist())}

Here is a sample:
{stock_sample}

2. `news_data`: Daily financial and Apple-related news.
It includes:
{', '.join(news_data.columns.tolist())}

Here is a sample:
{news_sample}

Your task is:
- Analyze the historical stock data for trends and patterns.
- Use the news content to understand recent events, sentiment, or other external signals.
- Based on these two data sources, **predict the next 14 days of Apple’s `close` stock price**.
- Your prediction should be in the form of a list or table, with each entry showing the predicted date and corresponding `close` price.

Assume that both datasets are cleaned and aligned by date. Use your reasoning to integrate numerical and textual information.
"""

    return prompt

# %%
# Created user_prompt
user_prompt = user_prompt(df, hist)

# %%
# My LLM model uses user_promt and system_prompt to predict close data
completion = openai.chat.completions.create(
    model='gpt-4o-mini',
    messages= [
    {"role": "system", "content": system_prompt},
    {"role": "user", "content": user_prompt}
    ],
)
print(completion.choices[0].message.content)
# Out:
# To forecast the next 14 days of Apple Inc.'s closing stock prices, we will utilize both historical stock data and relevant news content to derive a prediction. Let’s break down this process systematically:
#
# ### Step 1: Analyze Historical Stock Data
#
# 1. **General Trend**: We observe from the historical stock data that Apple Inc.'s closing prices have been extremely volatile over the last month. The company experienced a drop below $200 but has rebounded sharply thereafter.
#
# 2. **Recent Performance**: In the last week of data, Apple has had a fluctuating yet overall upward trend post a significant drop. The volatility suggests responses to both market conditions and internal events (like product announcements).
#
# 3. **Volatility**: The stock fluctuated significantly, suggesting a high degree of uncertainty. The last recorded closing price was $198.419998.
#
# ### Step 2: Analyze News Sentiment
#
# 1. **Latest Events**: The news records are rich with sentiment but predominantly neutral. Events such as product launches (WWDC 2025), software updates, and industry competition prevail in the recent headlines.
#
# 2. **Sentiment Analysis**: Majority of the sentiment appears neutral, indicating that there were no overwhelmingly positive or negative spikes in sentiment that could drastically sway the stock price in either direction.
#
# ### Step 3: Integrating the Analysis
#
# From the observations made:
# - The sharp recent uptick in price along with the neutral news sentiment suggests that the momentum may be stable but cautious.
# - Fluctuations in stock price indicate that we may see both potential rebounds and corrections.
#
# ### Step 4: Predicting Future Prices
#
# To estimate the next 14 days, we assume a slight upward trend while also accounting for potential dips in response to market conditions and sentiments. We apply a modest growth factor that aligns with average stock movements over similar historical periods.
#
# Without detailed statistical models or algorithms, a pragmatic approach based on historical data, observed trends, and news sentiment is adopted for the closing prices over the next two weeks.
#
# ### Predicted Closing Prices for the Next 14 Days
#
# | Date       | Predicted Close Price |
# |------------|-----------------------|
# | 2025-06-17 | $199.50               |
# | 2025-06-18 | $200.30               |
# | 2025-06-19 | $201.20               |
# | 2025-06-20 | $200.70               |
# | 2025-06-21 | $202.00               |
# | 2025-06-24 | $203.50               |
# | 2025-06-25 | $204.50               |
# | 2025-06-26 | $205.00               |
# | 2025-06-27 | $207.00               |
# | 2025-06-28 | $206.50               |
# | 2025-06-29 | $208.00               |
# | 2025-06-30 | $209.50               |
# | 2025-07-01 | $210.00               |
# | 2025-07-02 | $211.00               |
#
# This forecast assumes that the stock will continue to reflect gradual growth while being influenced by external market conditions and general investor sentiment, maintaining a balance between recovery and possible volatility. Further sophisticated analysis could improve accuracy.

# %% [markdown]
# # CONCLUSION
# We have come to the end of this project. I created an AI assistant for exchange trading. This AI assistant will trade on Apple stock price. However, this study is a preliminary study. It cannot be used in any stock trading transactions because the artificial intelligence assistant will not work with 100% accuracy.
#
# **I warn you: please do not use this system for stock market purchases.**
#
# Thank you for taking a look at my project. I will continue to share projects. If you want to be informed in advance, you can follow me from the links below.
#
# Bu projenin sonuna geldik. Borsa ticareti için bir AI asistanı oluşturdum. Bu AI asistanı Apple hisse senedi fiyatında işlem yapacak. Ancak bu çalışma bir ön çalışmadır. Yapay zeka asistanı %100 doğrulukla çalışmayacağı için herhangi bir hisse senedi ticareti işleminde kullanılamaz.
#
# **Uyarıyorum: Lütfen bu sistemi borsa alım satımlarında kullanmayın.**
#
# Projeme göz attığınız için teşekkür ederim. Projelerimi paylaşmaya devam edeceğim. Önceden haberdar olmak istiyorsanız aşağıdaki bağlantılardan beni takip edebilirsiniz.
#
# [LinkedIn](https://www.linkedin.com/in/ihsancenkiz/)<br>
# [GitHub](https://github.com/ihsncnkz)<br>
# [Kaggle](https://www.kaggle.com/ihsncnkz)
